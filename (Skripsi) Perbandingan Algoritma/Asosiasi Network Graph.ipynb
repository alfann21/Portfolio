# %%
import pandas as pa
from mlxtend.frequent_patterns import apriori, association_rules

# %%
data=pa.read_excel("Transaksi Penjualan Obat.xlsx")
data.head()
# Out:
#      Nomor Ref              Tanggal  Kode PLU                Nama Produk  \
# 0  RJJ-0000001  2022-03-02 00:00:00       400     SAKATONIK ABC GRAPE 30
# 1  RJJ-0000002  2022-03-02 00:00:00       294  MINYAK KAYU PUTIH LANG 60
# 2  RJJ-0000003  2022-03-02 00:00:00       290  MINYAK HERBA SINERGI 2020
# 3  RJJ-0000003  2022-03-02 00:00:00       325  NEUROBION 5 STRIP @10 TAB
# 4  RJJ-0000004  2022-03-03 00:00:00        36              AMLODIPIN 5MG
#
#   Satuan  Harga Satuan  QTY  Jum. Penjualan
# 0    PCS       17000.0    1         17000.0
# 1    PCS       23000.0    2         46000.0
# 2    PCS       35000.0    1         35000.0
# 3    PCS        2500.0    1          2500.0
# 4    PCS         400.0    3          1200.0

# %%
data.columns
# Out:
# Index(['Nomor Ref', 'Tanggal', 'Kode PLU', 'Nama Produk', 'Satuan',
#        'Harga Satuan', 'QTY', 'Jum. Penjualan'],
#       dtype='object')

# %%
data['Nama Produk']=data['Nama Produk'].str.strip()

data.dropna(axis=0,subset=['Nomor Ref'], inplace = True)
data['Nomor Ref']=data['Nomor Ref'].astype('str')

# %%
newdata=data.groupby(['Nomor Ref','Nama Produk'])['QTY'].sum().unstack().reset_index().fillna(0).set_index('Nomor Ref')
newdata
# Out:
# Nama Produk  ACETYLSISTEIN NULAB 200MG BOX 10 PCS STRIP@10 CAPS  \
# Nomor Ref
# RJJ-0000001                                                0.0
# RJJ-0000002                                                0.0
# RJJ-0000003                                                0.0
# RJJ-0000004                                                0.0
# RJJ-0000005                                                0.0
# ...                                                        ...
# RJJ-0000305                                                0.0
# RJJ-0000306                                                0.0
# RJJ-0000307                                                0.0
# RJJ-0000308                                                0.0
# RJJ-0000309                                                0.0
#
# Nama Produk  ALOCLAIR PLUS GEL 8 GRAM TUBE  AMBEVEN BOX 10 BLS @ 10 CAPS  \
# Nomor Ref
# RJJ-0000001                            0.0                           0.0
# RJJ-0000002                            0.0                           0.0
# RJJ-0000003                            0.0                           0.0
# RJJ-0000004                            0.0                           0.0
# RJJ-0000005                            0.0                           0.0
# ...                                    ...                           ...
# RJJ-0000305                            0.0                           0.0
# RJJ-0000306                            0.0                           0.0
# RJJ-0000307                            0.0                           0.0
# RJJ-0000308                            0.0                           0.0
# RJJ-0000309                            0.0                           0.0
#
# Nama Produk  AMLODIPIN 5MG  AMOXICILLIN 500 MG  ANAKONIDIN 60 ML  \
# Nomor Ref
# RJJ-0000001            0.0                 0.0               0.0
# RJJ-0000002            0.0                 0.0               0.0
# RJJ-0000003            0.0                 0.0               0.0
# RJJ-0000004            3.0                 0.0               0.0
# RJJ-0000005            0.0                 0.0               0.0
# ...                    ...                 ...               ...
# RJJ-0000305            0.0                 0.0               0.0
# RJJ-0000306            0.0                 0.0               0.0
# RJJ-0000307            0.0                 1.0               0.0
# RJJ-0000308            0.0                 0.0               0.0
# RJJ-0000309            0.0                 0.0               0.0
#
# Nama Produk  ANTANGIN CAIR JRG  ANTANGIN HABBATUSSAUDA CAIR  \
# Nomor Ref
# RJJ-0000001                0.0                          0.0
# RJJ-0000002                0.0                          0.0
# RJJ-0000003                0.0                          0.0
# RJJ-0000004                0.0                          0.0
# RJJ-0000005                3.0                          0.0
# ...                        ...                          ...
# RJJ-0000305                0.0                          0.0
# RJJ-0000306                0.0                          0.0
# RJJ-0000307                0.0                          0.0
# RJJ-0000308                0.0                          0.0
# RJJ-0000309                0.0                          0.0
#
# Nama Produk  ANTIS HANDSPRAY SANITIZER 30ML  ASAM MEFENAMAT 500 MG  ...  \
# Nomor Ref                                                           ...
# RJJ-0000001                             0.0                    0.0  ...
# RJJ-0000002                             0.0                    0.0  ...
# RJJ-0000003                             0.0                    0.0  ...
# RJJ-0000004                             0.0                    0.0  ...
# RJJ-0000005                             0.0                    0.0  ...
# ...                                     ...                    ...  ...
# RJJ-0000305                             0.0                    0.0  ...
# RJJ-0000306                             0.0                    0.0  ...
# RJJ-0000307                             0.0                    0.0  ...
# RJJ-0000308                             0.0                    0.0  ...
# RJJ-0000309                             0.0                    0.0  ...
#
# Nama Produk  SWEETY SILVER PANTS S32  TEMPRA DROPS RASA ANGGUR 15 ML  \
# Nomor Ref
# RJJ-0000001                      0.0                             0.0
# RJJ-0000002                      0.0                             0.0
# RJJ-0000003                      0.0                             0.0
# RJJ-0000004                      0.0                             0.0
# RJJ-0000005                      0.0                             0.0
# ...                              ...                             ...
# RJJ-0000305                      0.0                             0.0
# RJJ-0000306                      0.0                             0.0
# RJJ-0000307                      0.0                             0.0
# RJJ-0000308                      0.0                             0.0
# RJJ-0000309                      0.0                             0.0
#
# Nama Produk  THROMBOPHOB GEL 20 GR  VICEE JERUK 50 STRIP @2 TAB  \
# Nomor Ref
# RJJ-0000001                    0.0                          0.0
# RJJ-0000002                    0.0                          0.0
# RJJ-0000003                    0.0                          0.0
# RJJ-0000004                    0.0                          0.0
# RJJ-0000005                    0.0                          0.0
# ...                            ...                          ...
# RJJ-0000305                    0.0                          0.0
# RJJ-0000306                    0.0                          0.0
# RJJ-0000307                    0.0                          0.0
# RJJ-0000308                    0.0                          0.0
# RJJ-0000309                    0.0                          0.0
#
# Nama Produk  VICEE STRAWBERRY 50 STRIP @2 TAB  VITAL EAR OIL  \
# Nomor Ref
# RJJ-0000001                               0.0            0.0
# RJJ-0000002                               0.0            0.0
# RJJ-0000003                               0.0            0.0
# RJJ-0000004                               0.0            0.0
# RJJ-0000005                               0.0            0.0
# ...                                       ...            ...
# RJJ-0000305                               0.0            0.0
# RJJ-0000306                               0.0            0.0
# RJJ-0000307                               0.0            0.0
# RJJ-0000308                               0.0            0.0
# RJJ-0000309                               0.0            0.0
#
# Nama Produk  WOODS LOZENGES HONEY LEMON ISI 6  XONCE  ZAMBUK OINTMENT 25 GR  \
# Nomor Ref
# RJJ-0000001                               0.0    0.0                    0.0
# RJJ-0000002                               0.0    0.0                    0.0
# RJJ-0000003                               0.0    0.0                    0.0
# RJJ-0000004                               0.0    0.0                    0.0
# RJJ-0000005                               0.0    0.0                    0.0
# ...                                       ...    ...                    ...
# RJJ-0000305                               0.0    0.0                    0.0
# RJJ-0000306                               0.0    0.0                    0.0
# RJJ-0000307                               0.0    0.0                    0.0
# RJJ-0000308                               0.0    0.0                    0.0
# RJJ-0000309                               0.0    2.0                    0.0
#
# Nama Produk  ZEGAVIT
# Nomor Ref
# RJJ-0000001      0.0
# RJJ-0000002      0.0
# RJJ-0000003      0.0
# RJJ-0000004      0.0
# RJJ-0000005      0.0
# ...              ...
# RJJ-0000305      0.0
# RJJ-0000306      0.0
# RJJ-0000307      0.0
# RJJ-0000308      0.0
# RJJ-0000309      0.0
#
# [299 rows x 91 columns]

# %%
def hot_encode(x):
    if(x<= 0):
        return False
    if(x>=1):
        return True

# %%
newdata_encoded=newdata.applymap(hot_encode)
newdata=newdata_encoded
newdata
# Out:
# Nama Produk  ACETYLSISTEIN NULAB 200MG BOX 10 PCS STRIP@10 CAPS  \
# Nomor Ref
# RJJ-0000001                                              False
# RJJ-0000002                                              False
# RJJ-0000003                                              False
# RJJ-0000004                                              False
# RJJ-0000005                                              False
# ...                                                        ...
# RJJ-0000305                                              False
# RJJ-0000306                                              False
# RJJ-0000307                                              False
# RJJ-0000308                                              False
# RJJ-0000309                                              False
#
# Nama Produk  ALOCLAIR PLUS GEL 8 GRAM TUBE  AMBEVEN BOX 10 BLS @ 10 CAPS  \
# Nomor Ref
# RJJ-0000001                          False                         False
# RJJ-0000002                          False                         False
# RJJ-0000003                          False                         False
# RJJ-0000004                          False                         False
# RJJ-0000005                          False                         False
# ...                                    ...                           ...
# RJJ-0000305                          False                         False
# RJJ-0000306                          False                         False
# RJJ-0000307                          False                         False
# RJJ-0000308                          False                         False
# RJJ-0000309                          False                         False
#
# Nama Produk  AMLODIPIN 5MG  AMOXICILLIN 500 MG  ANAKONIDIN 60 ML  \
# Nomor Ref
# RJJ-0000001          False               False             False
# RJJ-0000002          False               False             False
# RJJ-0000003          False               False             False
# RJJ-0000004           True               False             False
# RJJ-0000005          False               False             False
# ...                    ...                 ...               ...
# RJJ-0000305          False               False             False
# RJJ-0000306          False               False             False
# RJJ-0000307          False                True             False
# RJJ-0000308          False               False             False
# RJJ-0000309          False               False             False
#
# Nama Produk  ANTANGIN CAIR JRG  ANTANGIN HABBATUSSAUDA CAIR  \
# Nomor Ref
# RJJ-0000001              False                        False
# RJJ-0000002              False                        False
# RJJ-0000003              False                        False
# RJJ-0000004              False                        False
# RJJ-0000005               True                        False
# ...                        ...                          ...
# RJJ-0000305              False                        False
# RJJ-0000306              False                        False
# RJJ-0000307              False                        False
# RJJ-0000308              False                        False
# RJJ-0000309              False                        False
#
# Nama Produk  ANTIS HANDSPRAY SANITIZER 30ML  ASAM MEFENAMAT 500 MG  ...  \
# Nomor Ref                                                           ...
# RJJ-0000001                           False                  False  ...
# RJJ-0000002                           False                  False  ...
# RJJ-0000003                           False                  False  ...
# RJJ-0000004                           False                  False  ...
# RJJ-0000005                           False                  False  ...
# ...                                     ...                    ...  ...
# RJJ-0000305                           False                  False  ...
# RJJ-0000306                           False                  False  ...
# RJJ-0000307                           False                  False  ...
# RJJ-0000308                           False                  False  ...
# RJJ-0000309                           False                  False  ...
#
# Nama Produk  SWEETY SILVER PANTS S32  TEMPRA DROPS RASA ANGGUR 15 ML  \
# Nomor Ref
# RJJ-0000001                    False                           False
# RJJ-0000002                    False                           False
# RJJ-0000003                    False                           False
# RJJ-0000004                    False                           False
# RJJ-0000005                    False                           False
# ...                              ...                             ...
# RJJ-0000305                    False                           False
# RJJ-0000306                    False                           False
# RJJ-0000307                    False                           False
# RJJ-0000308                    False                           False
# RJJ-0000309                    False                           False
#
# Nama Produk  THROMBOPHOB GEL 20 GR  VICEE JERUK 50 STRIP @2 TAB  \
# Nomor Ref
# RJJ-0000001                  False                        False
# RJJ-0000002                  False                        False
# RJJ-0000003                  False                        False
# RJJ-0000004                  False                        False
# RJJ-0000005                  False                        False
# ...                            ...                          ...
# RJJ-0000305                  False                        False
# RJJ-0000306                  False                        False
# RJJ-0000307                  False                        False
# RJJ-0000308                  False                        False
# RJJ-0000309                  False                        False
#
# Nama Produk  VICEE STRAWBERRY 50 STRIP @2 TAB  VITAL EAR OIL  \
# Nomor Ref
# RJJ-0000001                             False          False
# RJJ-0000002                             False          False
# RJJ-0000003                             False          False
# RJJ-0000004                             False          False
# RJJ-0000005                             False          False
# ...                                       ...            ...
# RJJ-0000305                             False          False
# RJJ-0000306                             False          False
# RJJ-0000307                             False          False
# RJJ-0000308                             False          False
# RJJ-0000309                             False          False
#
# Nama Produk  WOODS LOZENGES HONEY LEMON ISI 6  XONCE  ZAMBUK OINTMENT 25 GR  \
# Nomor Ref
# RJJ-0000001                             False  False                  False
# RJJ-0000002                             False  False                  False
# RJJ-0000003                             False  False                  False
# RJJ-0000004                             False  False                  False
# RJJ-0000005                             False  False                  False
# ...                                       ...    ...                    ...
# RJJ-0000305                             False  False                  False
# RJJ-0000306                             False  False                  False
# RJJ-0000307                             False  False                  False
# RJJ-0000308                             False  False                  False
# RJJ-0000309                             False   True                  False
#
# Nama Produk  ZEGAVIT
# Nomor Ref
# RJJ-0000001    False
# RJJ-0000002    False
# RJJ-0000003    False
# RJJ-0000004    False
# RJJ-0000005    False
# ...              ...
# RJJ-0000305    False
# RJJ-0000306    False
# RJJ-0000307    False
# RJJ-0000308    False
# RJJ-0000309    False
#
# [299 rows x 91 columns]

# %%
import time

start_time = time.time()
frq_items=apriori(newdata,min_support=0.01,use_colnames=True)
end_time = time.time()
total_time = end_time - start_time

rules1 = association_rules(frq_items, metric="confidence", min_threshold=0.5)

print("Frequent Itemsset:")
print(frq_items)

print("Association Rules:")
print(rules1)

print(f"\nWaktu komputasi Apriori: {total_time:.5f} detik")
# Out:
# Frequent Itemsset:
#      support                                           itemsets
# 0   0.013378  (ACETYLSISTEIN NULAB 200MG BOX 10 PCS STRIP@10...
# 1   0.010033                    (ALOCLAIR PLUS GEL 8 GRAM TUBE)
# 2   0.013378                     (AMBEVEN BOX 10 BLS @ 10 CAPS)
# 3   0.013378                                    (AMLODIPIN 5MG)
# 4   0.016722                               (AMOXICILLIN 500 MG)
# ..       ...                                                ...
# 71  0.013378                 (WOODS LOZENGES HONEY LEMON ISI 6)
# 72  0.026756                                            (XONCE)
# 73  0.013378                                          (ZEGAVIT)
# 74  0.010033     (CESSA BABY 0-2 TH BODY FIT 8 ML, SANMOL DROP)
# 75  0.010033  (PROMAG TAB 3 STRIP X 10 TAB, KETOMED SCALP SO...
#
# [76 rows x 2 columns]
# Association Rules:
#                          antecedents                        consequents  \
# 0  (CESSA BABY 0-2 TH BODY FIT 8 ML)                      (SANMOL DROP)
# 1                      (SANMOL DROP)  (CESSA BABY 0-2 TH BODY FIT 8 ML)
#
#    antecedent support  consequent support   support  confidence     lift  \
# 0            0.013378            0.013378  0.010033        0.75  56.0625
# 1            0.013378            0.013378  0.010033        0.75  56.0625
#
#    leverage  conviction  zhangs_metric
# 0  0.009854    3.946488        0.99548
# 1  0.009854    3.946488        0.99548
#
# Waktu komputasi Apriori: 0.00504 detik

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()

for _, rule in rules1.iterrows():
    G.add_edge(rule['antecedents'], rule['consequents'], weight=rule['support'])

pos = nx.spring_layout(G)

edge_labels = {(rule['antecedents'], rule['consequents']): ( rule['lift']) 
               for _, rule in rules1.iterrows()}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

nx.draw_networkx(G, pos, with_labels=True)

plt.show()
# Out:
# D:\anaconda3\envs\assosiasi\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# D:\anaconda3\envs\assosiasi\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])

# %%
start_time = time.time()
frq_items=apriori(newdata,min_support=0.01,use_colnames=True)
end_time = time.time()
total_time = end_time - start_time

rules2 = association_rules(frq_items, metric="confidence", min_threshold=0.3)

print("Frequent Itemsset:")
print(frq_items)

print("Association Rules:")
print(rules2)

print(f"\nWaktu komputasi Apriori: {total_time:.5f} detik")
# Out:
# Frequent Itemsset:
#      support                                           itemsets
# 0   0.013378  (ACETYLSISTEIN NULAB 200MG BOX 10 PCS STRIP@10...
# 1   0.010033                    (ALOCLAIR PLUS GEL 8 GRAM TUBE)
# 2   0.013378                     (AMBEVEN BOX 10 BLS @ 10 CAPS)
# 3   0.013378                                    (AMLODIPIN 5MG)
# 4   0.016722                               (AMOXICILLIN 500 MG)
# ..       ...                                                ...
# 71  0.013378                 (WOODS LOZENGES HONEY LEMON ISI 6)
# 72  0.026756                                            (XONCE)
# 73  0.013378                                          (ZEGAVIT)
# 74  0.010033     (CESSA BABY 0-2 TH BODY FIT 8 ML, SANMOL DROP)
# 75  0.010033  (PROMAG TAB 3 STRIP X 10 TAB, KETOMED SCALP SO...
#
# [76 rows x 2 columns]
# Association Rules:
#                          antecedents                        consequents  \
# 0  (CESSA BABY 0-2 TH BODY FIT 8 ML)                      (SANMOL DROP)
# 1                      (SANMOL DROP)  (CESSA BABY 0-2 TH BODY FIT 8 ML)
# 2      (PROMAG TAB 3 STRIP X 10 TAB)           (KETOMED SCALP SOLUTION)
# 3           (KETOMED SCALP SOLUTION)      (PROMAG TAB 3 STRIP X 10 TAB)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.013378            0.013378  0.010033       0.750  56.062500
# 1            0.013378            0.013378  0.010033       0.750  56.062500
# 2            0.026756            0.026756  0.010033       0.375  14.015625
# 3            0.026756            0.026756  0.010033       0.375  14.015625
#
#    leverage  conviction  zhangs_metric
# 0  0.009854    3.946488       0.995480
# 1  0.009854    3.946488       0.995480
# 2  0.009318    1.557191       0.954181
# 3  0.009318    1.557191       0.954181
#
# Waktu komputasi Apriori: 0.00451 detik

# %%
G = nx.DiGraph()

for _, rule in rules2.iterrows():
    G.add_edge(rule['antecedents'], rule['consequents'], weight=rule['support'])

pos = nx.spring_layout(G)

edge_labels = {(rule['antecedents'], rule['consequents']): ( rule['lift']) 
               for _, rule in rules2.iterrows()}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

nx.draw_networkx(G, pos, with_labels=True)

plt.show()
# Out:
# D:\anaconda3\envs\assosiasi\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# D:\anaconda3\envs\assosiasi\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])

# %%
import matplotlib.pyplot as plt
import numpy as np

algorithms = ['Apriori 1', 'Apriori 2', 'FP-Growth 1', 'FP-Growth 2', 'ECLAT 1', 'ECLAT 2']
time = [4.89, 4, 3, 2.02, 2, 2.14] 

x = np.arange(len(algorithms))  
width = 0.35  

fig, ax = plt.subplots()
rects1 = ax.bar(x, time, width)

ax.set_ylabel('Waktu Komputasi (milisecond)')
ax.set_title('Perbandingan Waktu Komputasi Algoritma Apriori, FP-Growth, ECLAT')
ax.set_xticks(x)
ax.set_xticklabels(algorithms)

def autolabel(rects):
    for rect in rects:
        h = rect.get_height()
        ax.annotate('{}'.format(h),
                    xy=(rect.get_x() + rect.get_width() / 2, h),
                    xytext=(0, 3),  
                    textcoords="offset points",
                    ha='center', va='bottom')

autolabel(rects1)

fig.tight_layout()

plt.show()
