# %%
import pandas as pa
from mlxtend.frequent_patterns import fpgrowth, association_rules

# %%
data=pa.read_excel("Transaksi Penjualan Obat.xlsx")
data.head()
# Out:
#      Nomor Ref              Tanggal  Kode PLU                Nama Produk  \
# 0  RJJ-0000001  2022-03-02 00:00:00       400     SAKATONIK ABC GRAPE 30
# 1  RJJ-0000002  2022-03-02 00:00:00       294  MINYAK KAYU PUTIH LANG 60
# 2  RJJ-0000003  2022-03-02 00:00:00       290  MINYAK HERBA SINERGI 2020
# 3  RJJ-0000003  2022-03-02 00:00:00       325  NEUROBION 5 STRIP @10 TAB
# 4  RJJ-0000004  2022-03-03 00:00:00        36              AMLODIPIN 5MG
#
#   Satuan  Harga Satuan  QTY  Jum. Penjualan
# 0    PCS       17000.0    1         17000.0
# 1    PCS       23000.0    2         46000.0
# 2    PCS       35000.0    1         35000.0
# 3    PCS        2500.0    1          2500.0
# 4    PCS         400.0    3          1200.0

# %%
data.columns
# Out:
# Index(['Nomor Ref', 'Tanggal', 'Kode PLU', 'Nama Produk', 'Satuan',
#        'Harga Satuan', 'QTY', 'Jum. Penjualan'],
#       dtype='object')

# %%
data['Nama Produk']=data['Nama Produk'].str.strip()

data.dropna(axis=0,subset=['Nomor Ref'], inplace = True)
data['Nomor Ref']=data['Nomor Ref'].astype('str')

# %%
newdata=data.groupby(['Nomor Ref','Nama Produk'])['QTY'].sum().unstack().reset_index().fillna(0).set_index('Nomor Ref')
newdata
# Out:
# Nama Produk  ACETYLSISTEIN NULAB 200MG BOX 10 PCS STRIP@10 CAPS  \
# Nomor Ref
# RJJ-0000001                                                0.0
# RJJ-0000002                                                0.0
# RJJ-0000003                                                0.0
# RJJ-0000004                                                0.0
# RJJ-0000005                                                0.0
# ...                                                        ...
# RJJ-0000305                                                0.0
# RJJ-0000306                                                0.0
# RJJ-0000307                                                0.0
# RJJ-0000308                                                0.0
# RJJ-0000309                                                0.0
#
# Nama Produk  ALOCLAIR PLUS GEL 8 GRAM TUBE  AMBEVEN BOX 10 BLS @ 10 CAPS  \
# Nomor Ref
# RJJ-0000001                            0.0                           0.0
# RJJ-0000002                            0.0                           0.0
# RJJ-0000003                            0.0                           0.0
# RJJ-0000004                            0.0                           0.0
# RJJ-0000005                            0.0                           0.0
# ...                                    ...                           ...
# RJJ-0000305                            0.0                           0.0
# RJJ-0000306                            0.0                           0.0
# RJJ-0000307                            0.0                           0.0
# RJJ-0000308                            0.0                           0.0
# RJJ-0000309                            0.0                           0.0
#
# Nama Produk  AMLODIPIN 5MG  AMOXICILLIN 500 MG  ANAKONIDIN 60 ML  \
# Nomor Ref
# RJJ-0000001            0.0                 0.0               0.0
# RJJ-0000002            0.0                 0.0               0.0
# RJJ-0000003            0.0                 0.0               0.0
# RJJ-0000004            3.0                 0.0               0.0
# RJJ-0000005            0.0                 0.0               0.0
# ...                    ...                 ...               ...
# RJJ-0000305            0.0                 0.0               0.0
# RJJ-0000306            0.0                 0.0               0.0
# RJJ-0000307            0.0                 1.0               0.0
# RJJ-0000308            0.0                 0.0               0.0
# RJJ-0000309            0.0                 0.0               0.0
#
# Nama Produk  ANTANGIN CAIR JRG  ANTANGIN HABBATUSSAUDA CAIR  \
# Nomor Ref
# RJJ-0000001                0.0                          0.0
# RJJ-0000002                0.0                          0.0
# RJJ-0000003                0.0                          0.0
# RJJ-0000004                0.0                          0.0
# RJJ-0000005                3.0                          0.0
# ...                        ...                          ...
# RJJ-0000305                0.0                          0.0
# RJJ-0000306                0.0                          0.0
# RJJ-0000307                0.0                          0.0
# RJJ-0000308                0.0                          0.0
# RJJ-0000309                0.0                          0.0
#
# Nama Produk  ANTIS HANDSPRAY SANITIZER 30ML  ASAM MEFENAMAT 500 MG  ...  \
# Nomor Ref                                                           ...
# RJJ-0000001                             0.0                    0.0  ...
# RJJ-0000002                             0.0                    0.0  ...
# RJJ-0000003                             0.0                    0.0  ...
# RJJ-0000004                             0.0                    0.0  ...
# RJJ-0000005                             0.0                    0.0  ...
# ...                                     ...                    ...  ...
# RJJ-0000305                             0.0                    0.0  ...
# RJJ-0000306                             0.0                    0.0  ...
# RJJ-0000307                             0.0                    0.0  ...
# RJJ-0000308                             0.0                    0.0  ...
# RJJ-0000309                             0.0                    0.0  ...
#
# Nama Produk  SWEETY SILVER PANTS S32  TEMPRA DROPS RASA ANGGUR 15 ML  \
# Nomor Ref
# RJJ-0000001                      0.0                             0.0
# RJJ-0000002                      0.0                             0.0
# RJJ-0000003                      0.0                             0.0
# RJJ-0000004                      0.0                             0.0
# RJJ-0000005                      0.0                             0.0
# ...                              ...                             ...
# RJJ-0000305                      0.0                             0.0
# RJJ-0000306                      0.0                             0.0
# RJJ-0000307                      0.0                             0.0
# RJJ-0000308                      0.0                             0.0
# RJJ-0000309                      0.0                             0.0
#
# Nama Produk  THROMBOPHOB GEL 20 GR  VICEE JERUK 50 STRIP @2 TAB  \
# Nomor Ref
# RJJ-0000001                    0.0                          0.0
# RJJ-0000002                    0.0                          0.0
# RJJ-0000003                    0.0                          0.0
# RJJ-0000004                    0.0                          0.0
# RJJ-0000005                    0.0                          0.0
# ...                            ...                          ...
# RJJ-0000305                    0.0                          0.0
# RJJ-0000306                    0.0                          0.0
# RJJ-0000307                    0.0                          0.0
# RJJ-0000308                    0.0                          0.0
# RJJ-0000309                    0.0                          0.0
#
# Nama Produk  VICEE STRAWBERRY 50 STRIP @2 TAB  VITAL EAR OIL  \
# Nomor Ref
# RJJ-0000001                               0.0            0.0
# RJJ-0000002                               0.0            0.0
# RJJ-0000003                               0.0            0.0
# RJJ-0000004                               0.0            0.0
# RJJ-0000005                               0.0            0.0
# ...                                       ...            ...
# RJJ-0000305                               0.0            0.0
# RJJ-0000306                               0.0            0.0
# RJJ-0000307                               0.0            0.0
# RJJ-0000308                               0.0            0.0
# RJJ-0000309                               0.0            0.0
#
# Nama Produk  WOODS LOZENGES HONEY LEMON ISI 6  XONCE  ZAMBUK OINTMENT 25 GR  \
# Nomor Ref
# RJJ-0000001                               0.0    0.0                    0.0
# RJJ-0000002                               0.0    0.0                    0.0
# RJJ-0000003                               0.0    0.0                    0.0
# RJJ-0000004                               0.0    0.0                    0.0
# RJJ-0000005                               0.0    0.0                    0.0
# ...                                       ...    ...                    ...
# RJJ-0000305                               0.0    0.0                    0.0
# RJJ-0000306                               0.0    0.0                    0.0
# RJJ-0000307                               0.0    0.0                    0.0
# RJJ-0000308                               0.0    0.0                    0.0
# RJJ-0000309                               0.0    2.0                    0.0
#
# Nama Produk  ZEGAVIT
# Nomor Ref
# RJJ-0000001      0.0
# RJJ-0000002      0.0
# RJJ-0000003      0.0
# RJJ-0000004      0.0
# RJJ-0000005      0.0
# ...              ...
# RJJ-0000305      0.0
# RJJ-0000306      0.0
# RJJ-0000307      0.0
# RJJ-0000308      0.0
# RJJ-0000309      0.0
#
# [299 rows x 91 columns]

# %%
def hot_encode(x):
    if(x<= 0):
        return False
    if(x>=1):
        return True

# %%
newdata_encoded=newdata.applymap(hot_encode)
newdata=newdata_encoded
newdata
# Out:
# Nama Produk  ACETYLSISTEIN NULAB 200MG BOX 10 PCS STRIP@10 CAPS  \
# Nomor Ref
# RJJ-0000001                                              False
# RJJ-0000002                                              False
# RJJ-0000003                                              False
# RJJ-0000004                                              False
# RJJ-0000005                                              False
# ...                                                        ...
# RJJ-0000305                                              False
# RJJ-0000306                                              False
# RJJ-0000307                                              False
# RJJ-0000308                                              False
# RJJ-0000309                                              False
#
# Nama Produk  ALOCLAIR PLUS GEL 8 GRAM TUBE  AMBEVEN BOX 10 BLS @ 10 CAPS  \
# Nomor Ref
# RJJ-0000001                          False                         False
# RJJ-0000002                          False                         False
# RJJ-0000003                          False                         False
# RJJ-0000004                          False                         False
# RJJ-0000005                          False                         False
# ...                                    ...                           ...
# RJJ-0000305                          False                         False
# RJJ-0000306                          False                         False
# RJJ-0000307                          False                         False
# RJJ-0000308                          False                         False
# RJJ-0000309                          False                         False
#
# Nama Produk  AMLODIPIN 5MG  AMOXICILLIN 500 MG  ANAKONIDIN 60 ML  \
# Nomor Ref
# RJJ-0000001          False               False             False
# RJJ-0000002          False               False             False
# RJJ-0000003          False               False             False
# RJJ-0000004           True               False             False
# RJJ-0000005          False               False             False
# ...                    ...                 ...               ...
# RJJ-0000305          False               False             False
# RJJ-0000306          False               False             False
# RJJ-0000307          False                True             False
# RJJ-0000308          False               False             False
# RJJ-0000309          False               False             False
#
# Nama Produk  ANTANGIN CAIR JRG  ANTANGIN HABBATUSSAUDA CAIR  \
# Nomor Ref
# RJJ-0000001              False                        False
# RJJ-0000002              False                        False
# RJJ-0000003              False                        False
# RJJ-0000004              False                        False
# RJJ-0000005               True                        False
# ...                        ...                          ...
# RJJ-0000305              False                        False
# RJJ-0000306              False                        False
# RJJ-0000307              False                        False
# RJJ-0000308              False                        False
# RJJ-0000309              False                        False
#
# Nama Produk  ANTIS HANDSPRAY SANITIZER 30ML  ASAM MEFENAMAT 500 MG  ...  \
# Nomor Ref                                                           ...
# RJJ-0000001                           False                  False  ...
# RJJ-0000002                           False                  False  ...
# RJJ-0000003                           False                  False  ...
# RJJ-0000004                           False                  False  ...
# RJJ-0000005                           False                  False  ...
# ...                                     ...                    ...  ...
# RJJ-0000305                           False                  False  ...
# RJJ-0000306                           False                  False  ...
# RJJ-0000307                           False                  False  ...
# RJJ-0000308                           False                  False  ...
# RJJ-0000309                           False                  False  ...
#
# Nama Produk  SWEETY SILVER PANTS S32  TEMPRA DROPS RASA ANGGUR 15 ML  \
# Nomor Ref
# RJJ-0000001                    False                           False
# RJJ-0000002                    False                           False
# RJJ-0000003                    False                           False
# RJJ-0000004                    False                           False
# RJJ-0000005                    False                           False
# ...                              ...                             ...
# RJJ-0000305                    False                           False
# RJJ-0000306                    False                           False
# RJJ-0000307                    False                           False
# RJJ-0000308                    False                           False
# RJJ-0000309                    False                           False
#
# Nama Produk  THROMBOPHOB GEL 20 GR  VICEE JERUK 50 STRIP @2 TAB  \
# Nomor Ref
# RJJ-0000001                  False                        False
# RJJ-0000002                  False                        False
# RJJ-0000003                  False                        False
# RJJ-0000004                  False                        False
# RJJ-0000005                  False                        False
# ...                            ...                          ...
# RJJ-0000305                  False                        False
# RJJ-0000306                  False                        False
# RJJ-0000307                  False                        False
# RJJ-0000308                  False                        False
# RJJ-0000309                  False                        False
#
# Nama Produk  VICEE STRAWBERRY 50 STRIP @2 TAB  VITAL EAR OIL  \
# Nomor Ref
# RJJ-0000001                             False          False
# RJJ-0000002                             False          False
# RJJ-0000003                             False          False
# RJJ-0000004                             False          False
# RJJ-0000005                             False          False
# ...                                       ...            ...
# RJJ-0000305                             False          False
# RJJ-0000306                             False          False
# RJJ-0000307                             False          False
# RJJ-0000308                             False          False
# RJJ-0000309                             False          False
#
# Nama Produk  WOODS LOZENGES HONEY LEMON ISI 6  XONCE  ZAMBUK OINTMENT 25 GR  \
# Nomor Ref
# RJJ-0000001                             False  False                  False
# RJJ-0000002                             False  False                  False
# RJJ-0000003                             False  False                  False
# RJJ-0000004                             False  False                  False
# RJJ-0000005                             False  False                  False
# ...                                       ...    ...                    ...
# RJJ-0000305                             False  False                  False
# RJJ-0000306                             False  False                  False
# RJJ-0000307                             False  False                  False
# RJJ-0000308                             False  False                  False
# RJJ-0000309                             False   True                  False
#
# Nama Produk  ZEGAVIT
# Nomor Ref
# RJJ-0000001    False
# RJJ-0000002    False
# RJJ-0000003    False
# RJJ-0000004    False
# RJJ-0000005    False
# ...              ...
# RJJ-0000305    False
# RJJ-0000306    False
# RJJ-0000307    False
# RJJ-0000308    False
# RJJ-0000309    False
#
# [299 rows x 91 columns]

# %%
import time

start_time = time.time()
frequent_itemsets = fpgrowth(newdata, min_support=0.01, use_colnames=True)
end_time = time.time()
total_time = end_time - start_time

rules1 = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

print("Frequent Itemsets:")
print(frequent_itemsets)

print("Association Rules:")
print(rules1)

print(f"\nWaktu komputasi FP-Growth: {total_time:.5f} detik")
# Out:
# Frequent Itemsets:
#      support                                           itemsets
# 0   0.013378                           (SAKATONIK ABC GRAPE 30)
# 1   0.026756                        (MINYAK KAYU PUTIH LANG 60)
# 2   0.036789                        (NEUROBION 5 STRIP @10 TAB)
# 3   0.013378                        (MINYAK HERBA SINERGI 2020)
# 4   0.013378                                    (AMLODIPIN 5MG)
# ..       ...                                                ...
# 71  0.013378                        (POLYSILANE SUSP 180 ML FB)
# 72  0.013378                  (NEUROBION FORTE 5 STRIP @10 TAB)
# 73  0.013378                         (CAVIPLEX MOM BTL 60 KAPL)
# 74  0.010033  (PROMAG TAB 3 STRIP X 10 TAB, KETOMED SCALP SO...
# 75  0.010033     (SANMOL DROP, CESSA BABY 0-2 TH BODY FIT 8 ML)
#
# [76 rows x 2 columns]
# Association Rules:
#                          antecedents                        consequents  \
# 0                      (SANMOL DROP)  (CESSA BABY 0-2 TH BODY FIT 8 ML)
# 1  (CESSA BABY 0-2 TH BODY FIT 8 ML)                      (SANMOL DROP)
#
#    antecedent support  consequent support   support  confidence     lift  \
# 0            0.013378            0.013378  0.010033        0.75  56.0625
# 1            0.013378            0.013378  0.010033        0.75  56.0625
#
#    leverage  conviction  zhangs_metric
# 0  0.009854    3.946488        0.99548
# 1  0.009854    3.946488        0.99548
#
# Waktu komputasi FP-Growth: 0.00250 detik

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.DiGraph()

for _, rule in rules1.iterrows():
    G.add_edge(rule['antecedents'], rule['consequents'], weight=rule['support'])

pos = nx.spring_layout(G)

edge_labels = {(rule['antecedents'], rule['consequents']): ( rule['lift']) 
               for _, rule in rules1.iterrows()}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

nx.draw_networkx(G, pos, with_labels=True)

plt.show()
# Out:
# D:\anaconda3\envs\assosiasi\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# D:\anaconda3\envs\assosiasi\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])

# %%
start_time = time.time()
frequent_itemsets = fpgrowth(newdata, min_support=0.01, use_colnames=True)
end_time = time.time()
total_time = end_time - start_time

rules2 = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)

print("Frequent Itemsets:")
print(frequent_itemsets)

print("Association Rules:")
print(rules2)

print(f"\nWaktu komputasi FP-Growth: {total_time:.5f} detik")
# Out:
# Frequent Itemsets:
#      support                                           itemsets
# 0   0.013378                           (SAKATONIK ABC GRAPE 30)
# 1   0.026756                        (MINYAK KAYU PUTIH LANG 60)
# 2   0.036789                        (NEUROBION 5 STRIP @10 TAB)
# 3   0.013378                        (MINYAK HERBA SINERGI 2020)
# 4   0.013378                                    (AMLODIPIN 5MG)
# ..       ...                                                ...
# 71  0.013378                        (POLYSILANE SUSP 180 ML FB)
# 72  0.013378                  (NEUROBION FORTE 5 STRIP @10 TAB)
# 73  0.013378                         (CAVIPLEX MOM BTL 60 KAPL)
# 74  0.010033  (PROMAG TAB 3 STRIP X 10 TAB, KETOMED SCALP SO...
# 75  0.010033     (SANMOL DROP, CESSA BABY 0-2 TH BODY FIT 8 ML)
#
# [76 rows x 2 columns]
# Association Rules:
#                          antecedents                        consequents  \
# 0      (PROMAG TAB 3 STRIP X 10 TAB)           (KETOMED SCALP SOLUTION)
# 1           (KETOMED SCALP SOLUTION)      (PROMAG TAB 3 STRIP X 10 TAB)
# 2                      (SANMOL DROP)  (CESSA BABY 0-2 TH BODY FIT 8 ML)
# 3  (CESSA BABY 0-2 TH BODY FIT 8 ML)                      (SANMOL DROP)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.026756            0.026756  0.010033       0.375  14.015625
# 1            0.026756            0.026756  0.010033       0.375  14.015625
# 2            0.013378            0.013378  0.010033       0.750  56.062500
# 3            0.013378            0.013378  0.010033       0.750  56.062500
#
#    leverage  conviction  zhangs_metric
# 0  0.009318    1.557191       0.954181
# 1  0.009318    1.557191       0.954181
# 2  0.009854    3.946488       0.995480
# 3  0.009854    3.946488       0.995480
#
# Waktu komputasi FP-Growth: 0.00300 detik

# %%
G = nx.DiGraph()

for _, rule in rules2.iterrows():
    G.add_edge(rule['antecedents'], rule['consequents'], weight=rule['support'])

pos = nx.spring_layout(G)

edge_labels = {(rule['antecedents'], rule['consequents']): ( rule['lift']) 
               for _, rule in rules2.iterrows()}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)

nx.draw_networkx(G, pos, with_labels=True)

plt.show()
# Out:
# D:\anaconda3\envs\assosiasi\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
# D:\anaconda3\envs\assosiasi\Lib\site-packages\pandas\core\dtypes\cast.py:1641: DeprecationWarning: np.find_common_type is deprecated.  Please use `np.result_type` or `np.promote_types`.
# See https://numpy.org/devdocs/release/1.25.0-notes.html and the docs for more information.  (Deprecated NumPy 1.25)
#   return np.find_common_type(types, [])
